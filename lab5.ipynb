# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1:

# %%
df = pd.DataFrame({'Name': ['Strom, Mrs. Wilhelm (Elna Matilda Persson)',
                            'Navratil, Mr. Michel ("Louis M Hoffman")', 'Minahan, Miss. Daisy E'],
                            'Age': [29,5, 33],'Sex':['female','male','female']})
df
# Out:
#                                          Name  Age     Sex
# 0  Strom, Mrs. Wilhelm (Elna Matilda Persson)   29  female
# 1    Navratil, Mr. Michel ("Louis M Hoffman")    5    male
# 2                      Minahan, Miss. Daisy E   33  female

# %% [markdown]
# # 2:

# %%
data1=pd.read_csv('titanic_csv.csv',sep=';')
data1
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0            454         1       1              Goldenberg, Mr. Samuel L
# 1            234         1       3        Asplund, Miss. Lillian Gertrud
# 2            556         0       1                    Wright, Mr. George
# 3            766         1       1  Hogeboom, Mrs. John C (Anna Andrews)
# 4            444         1       2             Reynaldo, Ms. Encarnacion
# ..           ...       ...     ...                                   ...
# 489          363         0       3       Barbara, Mrs. (Catherine David)
# 490          447         1       2     Mellinger, Miss. Madeleine Violet
# 491           95         0       3                     Coxon, Mr. Daniel
# 492           59         1       2          West, Miss. Constance Mirium
# 493           33         1       3              Glynn, Miss. Mary Agatha
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # 3:

# %%
data2=pd.read_csv('https://gist.githubusercontent.com/zaryanezrya/8b4ef51c707cb16d5e88a44dc00a1bb2/raw/41230f49c6268e072dbf102672f670be256922ab/gistfile1.txt',sep=',')
data2
# Out:
#      passengerid  survived  pclass  \
# 0            552         0       2
# 1            689         0       3
# 2            605         1       1
# 3            305         0       3
# 4            290         1       3
# ..           ...       ...     ...
# 495          482         0       2
# 496          155         0       3
# 497          851         0       3
# 498          850         1       1
# 499           77         0       3
#
#                                              name     sex   age  sibsp  parch  \
# 0                     Sharp, Mr. Percival James R    male  27.0      0      0
# 1                 Fischer, Mr. Eberhard Thelander    male  18.0      0      0
# 2                 Homer, Mr. Harry ("Mr E Haven")    male  35.0      0      0
# 3               Williams, Mr. Howard Hugh "Harry"    male   NaN      0      0
# 4                            Connolly, Miss. Kate  female  22.0      0      0
# ...

# %% [markdown]
# # 4:

# %%
data1=data1.rename(columns=str.lower)
data2=data2.rename(columns=str.lower)

# %%
data=pd.concat([data1,data2])
data
# Out:
#      passengerid  survived  pclass  \
# 0            454         1       1
# 1            234         1       3
# 2            556         0       1
# 3            766         1       1
# 4            444         1       2
# ..           ...       ...     ...
# 495          482         0       2
# 496          155         0       3
# 497          851         0       3
# 498          850         1       1
# 499           77         0       3
#
#                                              name     sex   age  sibsp  parch  \
# 0                        Goldenberg, Mr. Samuel L    male  49.0      1      0
# 1                  Asplund, Miss. Lillian Gertrud  female   5.0      4      2
# 2                              Wright, Mr. George    male  62.0      0      0
# 3            Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1      0
# 4                       Reynaldo, Ms. Encarnacion  female  28.0      0      0
# ...

# %%
data=data.drop_duplicates()
data
# Out:
#      passengerid  survived  pclass  \
# 0            454         1       1
# 1            234         1       3
# 2            556         0       1
# 3            766         1       1
# 4            444         1       2
# ..           ...       ...     ...
# 493          445         1       3
# 494          640         0       3
# 497          851         0       3
# 498          850         1       1
# 499           77         0       3
#
#                                              name     sex   age  sibsp  parch  \
# 0                        Goldenberg, Mr. Samuel L    male  49.0      1      0
# 1                  Asplund, Miss. Lillian Gertrud  female   5.0      4      2
# 2                              Wright, Mr. George    male  62.0      0      0
# 3            Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1      0
# 4                       Reynaldo, Ms. Encarnacion  female  28.0      0      0
# ...

# %% [markdown]
# # 5:

# %%
data=data.set_index('passengerid')
data.sort_values(by=['passengerid'])
# Out:
#              survived  pclass  \
# passengerid
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           name     sex   age  \
# passengerid
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # 6:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 454 to 77
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # 7:

# %%
data
# Out:
#              survived  pclass                                          name  \
# passengerid
# 454                 1       1                      Goldenberg, Mr. Samuel L
# 234                 1       3                Asplund, Miss. Lillian Gertrud
# 556                 0       1                            Wright, Mr. George
# 766                 1       1          Hogeboom, Mrs. John C (Anna Andrews)
# 444                 1       2                     Reynaldo, Ms. Encarnacion
# ...               ...     ...                                           ...
# 445                 1       3             Johannesen-Bratthammer, Mr. Bernt
# 640                 0       3                    Thorneycroft, Mr. Percival
# 851                 0       3       Andersson, Master. Sigvard Harald Elias
# 850                 1       1  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)
# 77                  0       3                             Staneff, Mr. Ivan
#
# ...

# %%
data.sort_index()
# Out:
#              survived  pclass  \
# passengerid
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           name     sex   age  \
# passengerid
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data.iloc[0]
# Out:
# survived                           1
# pclass                             1
# name        Goldenberg, Mr. Samuel L
# sex                             male
# age                             49.0
# sibsp                              1
# parch                              0
# ticket                         17453
# fare                         89.1042
# cabin                            C92
# embarked                           C
# Name: 454, dtype: object

# %%
data.loc[2]
# Out:
# survived                                                    1
# pclass                                                      1
# name        Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                    female
# age                                                      38.0
# sibsp                                                       1
# parch                                                       0
# ticket                                               PC 17599
# fare                                                  71.2833
# cabin                                                     C85
# embarked                                                    C
# Name: 2, dtype: object

# %%
tmp=data.iloc[0]
data.iloc[0]=data.loc[2]
data.loc[2]=tmp
data.iloc[0]
# Out:
# survived                                                    1
# pclass                                                      1
# name        Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                    female
# age                                                      38.0
# sibsp                                                       1
# parch                                                       0
# ticket                                               PC 17599
# fare                                                  71.2833
# cabin                                                     C85
# embarked                                                    C
# Name: 454, dtype: object

# %%
data.loc[2]
# Out:
# survived                           1
# pclass                             1
# name        Goldenberg, Mr. Samuel L
# sex                             male
# age                             49.0
# sibsp                              1
# parch                              0
# ticket                         17453
# fare                         89.1042
# cabin                            C92
# embarked                           C
# Name: 2, dtype: object

# %% [markdown]
# # 8:

# %%
dict1 = {'female': 'f', 'male': 'm'}

data['sex'] = data['sex'].map(dict1)
data
# Out:
#              survived  pclass  \
# passengerid
# 454                 1       1
# 234                 1       3
# 556                 0       1
# 766                 1       1
# 444                 1       2
# ...               ...     ...
# 445                 1       3
# 640                 0       3
# 851                 0       3
# 850                 1       1
# 77                  0       3
#
#                                                           name sex   age  \
# passengerid
# 454          Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 234                             Asplund, Miss. Lillian Gertrud   f   5.0
# 556                                         Wright, Mr. George   m  62.0
# 766                       Hogeboom, Mrs. John C (Anna Andrews)   f  51.0
# 444                                  Reynaldo, Ms. Encarnacion   f  28.0
# ...                                                        ...  ..   ...
# ...

# %% [markdown]
# # 9:

# %%
df1=data.groupby('ticket')['name'].count()
tck=df1[df1>=6]
tck
# Out:
# ticket
# 1601        7
# 3101295     6
# 347082      7
# 347088      6
# CA 2144     6
# CA. 2343    7
# Name: name, dtype: int64

# %%
data[data['ticket'].isin(tck.index)]
# Out:
#              survived  pclass  \
# passengerid
# 160                 0       3
# 820                 0       3
# 168                 0       3
# 481                 0       3
# 847                 0       3
# 543                 0       3
# 72                  0       3
# 679                 0       3
# 793                 0       3
# 635                 0       3
# 170                 0       3
# 814                 0       3
# 75                  1       3
# 644                 1       3
# 64                  0       3
# 120                 0       3
# 387                 0       3
# 510                 1       3
# 542                 0       3
# 643                 0       3
# 839                 1       3
# 639                 0       3
# 60                  0       3
# 611                 0       3
# 325                 0       3
# 181                 0       3
# 864                 0       3
# 825                 0       3
# 51                  0       3
# ...

# %% [markdown]
# # 10:

# %%
df=df.rename(columns=str.lower)
intersection=data[data['name'].isin(df['name'])]
intersection
# Out:
#              survived  pclass                                        name sex  \
# passengerid
# 413                 1       1                      Minahan, Miss. Daisy E   f
# 149                 0       2    Navratil, Mr. Michel ("Louis M Hoffman")   m
# 252                 0       3  Strom, Mrs. Wilhelm (Elna Matilda Persson)   f
#
#               age  sibsp  parch  ticket     fare cabin embarked
# passengerid
# 413          33.0      1      0   19928  90.0000   C78        Q
# 149          36.5      0      2  230080  26.0000    F2        S
# 252          29.0      1      1  347054  10.4625    G6        S

# %%
company = data[data['cabin'].isin(intersection['cabin'])]
company
# Out:
#              survived  pclass  \
# passengerid
# 413                 1       1
# 246                 0       1
# 194                 1       2
# 206                 0       3
# 149                 0       2
# 395                 1       3
# 252                 0       3
# 341                 1       2
# 11                  1       3
#
#                                                           name sex   age  \
# passengerid
# 413                                     Minahan, Miss. Daisy E   f  33.0
# 246                                Minahan, Dr. William Edward   m  44.0
# 194                                 Navratil, Master. Michel M   m   3.0
# 206                                 Strom, Miss. Telma Matilda   f   2.0
# 149                   Navratil, Mr. Michel ("Louis M Hoffman")   m  36.5
# 395          Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...   f  24.0
# 252                 Strom, Mrs. Wilhelm (Elna Matilda Persson)   f  29.0
# ...

# %% [markdown]
# # 11:

# %%
data['birthyear'] = 1912-data['age']
data
# Out:
#              survived  pclass  \
# passengerid
# 454                 1       1
# 234                 1       3
# 556                 0       1
# 766                 1       1
# 444                 1       2
# ...               ...     ...
# 445                 1       3
# 640                 0       3
# 851                 0       3
# 850                 1       1
# 77                  0       3
#
#                                                           name sex   age  \
# passengerid
# 454          Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 234                             Asplund, Miss. Lillian Gertrud   f   5.0
# 556                                         Wright, Mr. George   m  62.0
# 766                       Hogeboom, Mrs. John C (Anna Andrews)   f  51.0
# 444                                  Reynaldo, Ms. Encarnacion   f  28.0
# ...                                                        ...  ..   ...
# ...

# %% [markdown]
# # 12:

# %%
cab=data.groupby('cabin')['name'].count()
cab
# Out:
# cabin
# A10    1
# A14    1
# A16    1
# A19    1
# A20    1
#       ..
# F33    3
# F38    1
# F4     2
# G6     4
# T      1
# Name: name, Length: 147, dtype: int64

# %%
data['companion'] = data['cabin'].map(cab)
data.sort_index()
# Out:
#              survived  pclass                                          name  \
# passengerid
# 1                   0       3                       Braund, Mr. Owen Harris
# 2                   1       1                      Goldenberg, Mr. Samuel L
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# # 13:

# %%
data
# Out:
#              survived  pclass  \
# passengerid
# 454                 1       1
# 234                 1       3
# 556                 0       1
# 766                 1       1
# 444                 1       2
# ...               ...     ...
# 445                 1       3
# 640                 0       3
# 851                 0       3
# 850                 1       1
# 77                  0       3
#
#                                                           name sex   age  \
# passengerid
# 454          Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 234                             Asplund, Miss. Lillian Gertrud   f   5.0
# 556                                         Wright, Mr. George   m  62.0
# 766                       Hogeboom, Mrs. John C (Anna Andrews)   f  51.0
# 444                                  Reynaldo, Ms. Encarnacion   f  28.0
# ...                                                        ...  ..   ...
# ...

# %%
data.sort_index()
# Out:
#              survived  pclass                                          name  \
# passengerid
# 1                   0       3                       Braund, Mr. Owen Harris
# 2                   1       1                      Goldenberg, Mr. Samuel L
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
data.iloc[0]
# Out:
# survived                                                     1
# pclass                                                       1
# name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                          f
# age                                                       38.0
# sibsp                                                        1
# parch                                                        0
# ticket                                                PC 17599
# fare                                                   71.2833
# cabin                                                      C85
# embarked                                                     C
# birthyear                                               1874.0
# companion                                                  1.0
# Name: 454, dtype: object

# %%
data.loc[1]
# Out:
# survived                           0
# pclass                             3
# name         Braund, Mr. Owen Harris
# sex                                m
# age                             22.0
# sibsp                              1
# parch                              0
# ticket                     A/5 21171
# fare                            7.25
# cabin                            NaN
# embarked                           S
# birthyear                     1890.0
# companion                        NaN
# Name: 1, dtype: object

# %%
tmp=data.iloc[0]
data.iloc[0]=data.loc[1]
data.loc[1]=tmp
data.iloc[0]
# Out:
# survived                           0
# pclass                             3
# name         Braund, Mr. Owen Harris
# sex                                m
# age                             22.0
# sibsp                              1
# parch                              0
# ticket                     A/5 21171
# fare                            7.25
# cabin                            NaN
# embarked                           S
# birthyear                     1890.0
# companion                        NaN
# Name: 454, dtype: object

# %%
data.loc[1]
# Out:
# survived                                                     1
# pclass                                                       1
# name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                          f
# age                                                       38.0
# sibsp                                                        1
# parch                                                        0
# ticket                                                PC 17599
# fare                                                   71.2833
# cabin                                                      C85
# embarked                                                     C
# birthyear                                               1874.0
# companion                                                  1.0
# Name: 1, dtype: object

# %% [markdown]
# # 14:

# %%
data.to_csv('C:/Users/djego/OneDrive/Рабочий стол/practicum/out.csv',sep=';')

# %% [markdown]
# # 15:

# %%
data.sort_values(by='fare',ascending=False).head(10)
# Out:
#              survived  pclass                                   name sex  \
# passengerid
# 680                 1       1     Cardeza, Mr. Thomas Drake Martinez   m
# 259                 1       1                       Ward, Miss. Anna   f
# 738                 1       1                 Lesurer, Mr. Gustave J   m
# 89                  1       1             Fortune, Miss. Mabel Helen   f
# 28                  0       1         Fortune, Mr. Charles Alexander   m
# 439                 0       1                      Fortune, Mr. Mark   m
# 342                 1       1         Fortune, Miss. Alice Elizabeth   f
# 312                 1       1             Ryerson, Miss. Emily Borie   f
# 743                 1       1  Ryerson, Miss. Susan Parker "Suzette"   f
# 119                 0       1               Baxter, Mr. Quigg Edmond   m
#
#               age  sibsp  parch    ticket      fare            cabin embarked  \
# passengerid
# ...

# %% [markdown]
# # 16:

# %%
print(f"Всего было на корабле:{data.shape[0]}")
print(f"Всего выжило:{data[data['survived']==1].shape[0]}")
# Out:
# Всего было на корабле:891
# Всего выжило:342

# %%
print(f"Мужчин выжило:{data[(data['survived']==1) & (data['sex']=='m')].shape[0]}" )
print(f"Мужчин не выжило:{data[(data['survived']==0) & (data['sex']=='m')].shape[0]}" )

print(f"Женщин выжило:{data[(data['survived']==1) & (data['sex']=='f')].shape[0]}" )
print(f"Женщин не выжило:{data[(data['survived']==0) & (data['sex']=='f')].shape[0]}" )
# Out:
# Мужчин выжило:109
# Мужчин не выжило:468
# Женщин выжило:233
# Женщин не выжило:81

# %% [markdown]
# # 17:

# %%
df1=data.groupby('pclass')['survived'].count()
df1
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# Name: survived, dtype: int64

# %%
for i in df1.index:
    print(f"Выжило пассажиров {i}-класса:{data[(data['survived']==1) & (data['pclass']==i)].shape[0]}" )
    print(f"Не выжило пассажиров {i}-класса:{data[(data['survived']==0) & (data['pclass']==i)].shape[0]}" )
# Out:
# Выжило пассажиров 1-класса:136
# Не выжило пассажиров 1-класса:80
# Выжило пассажиров 2-класса:87
# Не выжило пассажиров 2-класса:97
# Выжило пассажиров 3-класса:119
# Не выжило пассажиров 3-класса:372
